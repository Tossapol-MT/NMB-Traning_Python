# %% [markdown]
# # Automate read excel

# %%
import pandas as pd

# %%
df = pd.read_excel(r'D:\NMB-Traning_Python\src\data\sales_data\2021\April.xlsx')
df
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          7fb801a5        Chicago  ACTIVE       2019-04-01  Silver
# 1          8e8bdb2a  San Francisco  ACTIVE       2019-04-01  Silver
# 2          239db9b6  Washington DC  ACTIVE       2019-04-01  Silver
# 3          7ccb13ab  San Francisco  ACTIVE       2019-04-01    Gold
# 4          c18e82d9        Chicago  ACTIVE       2019-04-01  Bronze
# ...             ...            ...     ...              ...     ...
# 7428       b3fcd96c         Boston  ACTIVE       2019-04-30  Bronze
# 7429       eec9e52a  San Francisco  ACTIVE       2019-04-30  Silver
# 7430       a9c90deb       New York  ACTIVE       2019-04-30  Bronze
# 7431       d585c5c1       New York  ACTIVE       2019-04-30  Silver
# 7432       f30b34e7  San Francisco  ACTIVE       2019-04-30  Silver
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   14.25
# 2              NEW   14.25
# 3              NEW   19.35
# 4              NEW   12.20
# ...            ...     ...
# 7428           NEW   12.20
# 7429           NEW   14.25
# 7430           NEW   12.20
# 7431           NEW   14.25
# 7432           NEW   14.25
#
# [7433 rows x 7 columns]

# %% [markdown]
# ## read multiple file excel

# %%
import os 

xlsx_file_lists = []

path = r'D:\NMB-Traning_Python\src\data\sales_data'
for root, dirs, files in os.walk(path):
    # print(root)
    # print(dirs) # Name of folders loop form root
    # print(files) #Name of files 
    for name in files:
        # print(root)
        # print(name)
        file_path = os.path.join(root,name)
        # print(file_path)
        xlsx_file_lists.append(file_path)
print(xlsx_file_lists)
# Out:
# ['D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\April.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\August.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\December.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\February.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\January.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\July.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\June.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\March.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\May.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\November.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\October.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2021\\September.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\April.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\August.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\December.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\February.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\January.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\July.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\June.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\March.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\May.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\November.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\October.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\September.xlsx']

# %%
df = pd.read_excel(xlsx_file_lists[0])
df
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          7fb801a5        Chicago  ACTIVE       2019-04-01  Silver
# 1          8e8bdb2a  San Francisco  ACTIVE       2019-04-01  Silver
# 2          239db9b6  Washington DC  ACTIVE       2019-04-01  Silver
# 3          7ccb13ab  San Francisco  ACTIVE       2019-04-01    Gold
# 4          c18e82d9        Chicago  ACTIVE       2019-04-01  Bronze
# ...             ...            ...     ...              ...     ...
# 7428       b3fcd96c         Boston  ACTIVE       2019-04-30  Bronze
# 7429       eec9e52a  San Francisco  ACTIVE       2019-04-30  Silver
# 7430       a9c90deb       New York  ACTIVE       2019-04-30  Bronze
# 7431       d585c5c1       New York  ACTIVE       2019-04-30  Silver
# 7432       f30b34e7  San Francisco  ACTIVE       2019-04-30  Silver
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   14.25
# 2              NEW   14.25
# 3              NEW   19.35
# 4              NEW   12.20
# ...            ...     ...
# 7428           NEW   12.20
# 7429           NEW   14.25
# 7430           NEW   12.20
# 7431           NEW   14.25
# 7432           NEW   14.25
#
# [7433 rows x 7 columns]

# %%
msg = r'D:\NMB-Traning_Python\src\data\sales_data\2021\April.xlsx'

print(msg.split("\\"))
print(msg.split("\\")[5])
# Out:
# ['D:', 'NMB-Traning_Python', 'src', 'data', 'sales_data', '2021', 'April.xlsx']
# 2021

# %%
for f in xlsx_file_lists:
    if f.split("\\")[5] == "2021":
        print(f)
# Out:
# D:\NMB-Traning_Python\src\data\sales_data\2021\April.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\August.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\December.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\February.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\January.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\July.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\June.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\March.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\May.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\November.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\October.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2021\September.xlsx

# %%
for f in xlsx_file_lists:
    if f.split("\\")[6].split(".")[0] == "April":
        print(f)
# Out:
# D:\NMB-Traning_Python\src\data\sales_data\2021\April.xlsx
# D:\NMB-Traning_Python\src\data\sales_data\2022\April.xlsx

# %%
for f in xlsx_file_lists:
    if f.split("\\")[5] == "2022":
        if f.split("\\")[6].split(".")[0] == "April":
            print(f)
# Out:
# D:\NMB-Traning_Python\src\data\sales_data\2022\April.xlsx

# %%
import datetime
today = datetime.date.today()
year = today.year-1
# print(year)

for f in xlsx_file_lists:
    if f.split("\\")[5] == str(year):
        if f.split("\\")[6].split(".")[0] == "April":
            # print(f)
            df = pd.read_excel(f)
df
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          7fb801a5        Chicago  ACTIVE       2019-04-01  Silver
# 1          8e8bdb2a  San Francisco  ACTIVE       2019-04-01  Silver
# 2          239db9b6  Washington DC  ACTIVE       2019-04-01  Silver
# 3          7ccb13ab  San Francisco  ACTIVE       2019-04-01    Gold
# 4          c18e82d9        Chicago  ACTIVE       2019-04-01  Bronze
# ...             ...            ...     ...              ...     ...
# 7428       b3fcd96c         Boston  ACTIVE       2019-04-30  Bronze
# 7429       eec9e52a  San Francisco  ACTIVE       2019-04-30  Silver
# 7430       a9c90deb       New York  ACTIVE       2019-04-30  Bronze
# 7431       d585c5c1       New York  ACTIVE       2019-04-30  Silver
# 7432       f30b34e7  San Francisco  ACTIVE       2019-04-30  Silver
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   14.25
# 2              NEW   14.25
# 3              NEW   19.35
# 4              NEW   12.20
# ...            ...     ...
# 7428           NEW   12.20
# 7429           NEW   14.25
# 7430           NEW   12.20
# 7431           NEW   14.25
# 7432           NEW   14.25
#
# [7433 rows x 7 columns]

# %% [markdown]
# ## Excample

# %%
today = datetime.date.today()
year = today.year-1
# print(year)

for f in xlsx_file_lists:
    if f.split("\\")[5] == str(year):
        if f.split("\\")[6]:
            # print(f)
            df = pd.read_excel(f)
df
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          1625da17       New York  ACTIVE       2019-09-02  Silver
# 1          a60801a8         Boston  ACTIVE       2019-09-02  Silver
# 2          478f5985       New York  ACTIVE       2019-09-02  Silver
# 3          ca84fd4c      Las Vegas  ACTIVE       2019-09-02  Silver
# 4          69fa39a9         Boston  ACTIVE       2019-09-02  Bronze
# ...             ...            ...     ...              ...     ...
# 7347       53a449b0       New York  ACTIVE       2019-09-30  Silver
# 7348       35b46c26         Boston  ACTIVE       2019-09-30  Silver
# 7349       9e498c85        Chicago  ACTIVE       2019-09-30  Silver
# 7350       5841d16e  San Francisco  ACTIVE       2019-09-30  Silver
# 7351       86937799        Chicago  ACTIVE       2019-09-30    Gold
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   14.25
# 2              NEW   14.25
# 3              NEW   14.25
# 4              NEW   12.20
# ...            ...     ...
# 7347           NEW   14.25
# 7348           NEW   14.25
# 7349           NEW   14.25
# 7350           NEW   14.25
# 7351           NEW   19.35
#
# [7352 rows x 7 columns]

# %%
xlsx_file_lists = []

path = r'D:\NMB-Traning_Python\src\data\sales_data'
for root, dirs, files in os.walk(path):
    for name in files:
        file_path = os.path.join(root,name)
        if file_path.split("\\")[5] == str(year):
            xlsx_file_lists.append(file_path)
print(xlsx_file_lists)
# Out:
# ['D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\April.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\August.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\December.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\February.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\January.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\July.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\June.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\March.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\May.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\November.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\October.xlsx', 'D:\\NMB-Traning_Python\\src\\data\\sales_data\\2022\\September.xlsx']

# %%
df_lists = []
for f in xlsx_file_lists:
    df = pd.read_excel(f)
    df_lists.append(df)
df_lists
# Out:
# [     transaction_id          store  status transaction_date    plan  \
#  0          7fb801a5        Chicago  ACTIVE       2019-04-01  Silver
#  1          8e8bdb2a  San Francisco  ACTIVE       2019-04-01  Silver
#  2          239db9b6  Washington DC  ACTIVE       2019-04-01  Silver
#  3          7ccb13ab  San Francisco  ACTIVE       2019-04-01    Gold
#  4          c18e82d9        Chicago  ACTIVE       2019-04-01  Bronze
#  ...             ...            ...     ...              ...     ...
#  7428       b3fcd96c         Boston  ACTIVE       2019-04-30  Bronze
#  7429       eec9e52a  San Francisco  ACTIVE       2019-04-30  Silver
#  7430       a9c90deb       New York  ACTIVE       2019-04-30  Bronze
#  7431       d585c5c1       New York  ACTIVE       2019-04-30  Silver
#  7432       f30b34e7  San Francisco  ACTIVE       2019-04-30  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   19.35
#  4              NEW   12.20
#  ...            ...     ...
#  7428           NEW   12.20
#  7429           NEW   14.25
#  7430           NEW   12.20
#  7431           NEW   14.25
#  7432           NEW   14.25
#
#  [7433 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          8d2b0582        Chicago  ACTIVE       2019-08-01  Silver
#  1          61e3773d        Chicago  ACTIVE       2019-08-01    Gold
#  2          52b3f422       New York  ACTIVE       2019-08-01  Bronze
#  3          ae0498f2        Chicago  ACTIVE       2019-08-01  Silver
#  4          7d1f5d57       New York  ACTIVE       2019-08-01  Silver
#  ...             ...            ...     ...              ...     ...
#  8417       47f7aca1  San Francisco  ACTIVE       2019-08-30  Silver
#  8418       2bdcceba         Boston  ACTIVE       2019-08-30  Silver
#  8419       e0aa3c08        Chicago  ACTIVE       2019-08-30  Silver
#  8420       aff115c2  San Francisco  ACTIVE       2019-08-30  Silver
#  8421       0bed8c3d       New York  ACTIVE       2019-08-30  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   19.35
#  2              NEW   12.20
#  3              NEW   14.25
#  4              NEW   14.25
#  ...            ...     ...
#  8417           NEW   14.25
#  8418           NEW   14.25
#  8419           NEW   14.25
#  8420           NEW   14.25
#  8421           NEW   14.25
#
#  [8422 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          0c84fc60       New York  ACTIVE       2019-12-02  Silver
#  1          f369c701  San Francisco  ACTIVE       2019-12-02  Bronze
#  2          1c2558bf        Chicago  ACTIVE       2019-12-02  Silver
#  3          3f98abc7  San Francisco  ACTIVE       2019-12-02  Silver
#  4          1ca71cb6       New York  ACTIVE       2019-12-02  Silver
#  ...             ...            ...     ...              ...     ...
#  7359       07da9a05       New York  ACTIVE       2019-12-31  Silver
#  7360       a776b812  San Francisco  ACTIVE       2019-12-31  Silver
#  7361       16a9246f       New York  ACTIVE       2019-12-31  Silver
#  7362       9ff448be       New York  ACTIVE       2019-12-31    Gold
#  7363       edb00d25       New York  ACTIVE       2019-12-31  Bronze
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   12.20
#  2              NEW   14.25
#  3              NEW   14.25
#  4              NEW   14.25
#  ...            ...     ...
#  7359           NEW   14.25
#  7360           NEW   14.25
#  7361           NEW   14.25
#  7362           NEW   19.35
#  7363           NEW   12.20
#
#  [7364 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          629b9f16       New York  ACTIVE       2019-02-01  Silver
#  1          2f57ac6c      Las Vegas  ACTIVE       2019-02-01  Silver
#  2          45e063e6      Las Vegas  ACTIVE       2019-02-01  Silver
#  3          6ef3a43a       New York  ACTIVE       2019-02-01  Silver
#  4          89f0cec1  San Francisco  ACTIVE       2019-02-01    Gold
#  ...             ...            ...     ...              ...     ...
#  8489       d0782c26        Chicago  ACTIVE       2019-02-28  Silver
#  8490       95c7977e  San Francisco  ACTIVE       2019-02-28  Silver
#  8491       919c37d1       New York  ACTIVE       2019-02-28  Silver
#  8492       b1820c05       New York  ACTIVE       2019-02-28  Bronze
#  8493       efe816e4      Las Vegas  ACTIVE       2019-02-28  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   14.25
#  4              NEW   19.35
#  ...            ...     ...
#  8489           NEW   14.25
#  8490           NEW   14.25
#  8491           NEW   14.25
#  8492           NEW   12.20
#  8493           NEW   14.25
#
#  [8494 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          abfbdd6d        Chicago  ACTIVE       2019-01-01  Silver
#  1          136a9997  San Francisco  ACTIVE       2019-01-01    Gold
#  2          c6688f32  San Francisco  ACTIVE       2019-01-01  Bronze
#  3          6ef349c1        Chicago  ACTIVE       2019-01-01    Gold
#  4          22066f29  San Francisco  ACTIVE       2019-01-01  Silver
#  ...             ...            ...     ...              ...     ...
#  9488       b487a1a6       New York  ACTIVE       2019-01-31  Silver
#  9489       9ab1fb48         Boston  ACTIVE       2019-01-31  Bronze
#  9490       08766c08  San Francisco  ACTIVE       2019-01-31  Silver
#  9491       3e56df84         Boston  ACTIVE       2019-01-31  Bronze
#  9492       2f28e861  Washington DC  ACTIVE       2019-01-31  Bronze
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   19.35
#  2              NEW   12.20
#  3              NEW   19.35
#  4              NEW   14.25
#  ...            ...     ...
#  9488           NEW   14.25
#  9489           NEW   12.20
#  9490           NEW   14.25
#  9491           NEW   12.20
#  9492           NEW   12.20
#
#  [9493 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          b82c1d77       New York  ACTIVE       2019-07-01  Silver
#  1          05c2cb05       New York  ACTIVE       2019-07-01  Silver
#  2          62e4c1ff       New York  ACTIVE       2019-07-01  Silver
#  3          536437fb       New York  ACTIVE       2019-07-01    Gold
#  4          5c126e56  San Francisco  ACTIVE       2019-07-01  Silver
#  ...             ...            ...     ...              ...     ...
#  7159       f05ebfda         Boston  ACTIVE       2019-07-31  Silver
#  7160       dd1e218b  San Francisco  ACTIVE       2019-07-31  Silver
#  7161       6ecfabf4        Chicago  ACTIVE       2019-07-31  Silver
#  7162       063a64a3       New York  ACTIVE       2019-07-31    Gold
#  7163       bd059d1a  San Francisco  ACTIVE       2019-07-31  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   19.35
#  4              NEW   14.25
#  ...            ...     ...
#  7159           NEW   14.25
#  7160           NEW   14.25
#  7161           NEW   14.25
#  7162           NEW   19.35
#  7163           NEW   14.25
#
#  [7164 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          85b9aadf         Boston  ACTIVE       2019-06-03    Gold
#  1          dbc4b91a  San Francisco  ACTIVE       2019-06-03  Silver
#  2          1c425787       New York  ACTIVE       2019-06-03  Silver
#  3          7ba76b0f  San Francisco  ACTIVE       2019-06-03    Gold
#  4          f52e41d9       New York  ACTIVE       2019-06-03  Silver
#  ...             ...            ...     ...              ...     ...
#  8569       9418df9f        Chicago  ACTIVE       2019-06-28  Silver
#  8570       c9ee14da      Las Vegas  ACTIVE       2019-06-28  Silver
#  8571       54026b4a       New York  ACTIVE       2019-06-28  Silver
#  8572       438b3952       New York  ACTIVE       2019-06-28    Gold
#  8573       ac093715       New York  ACTIVE       2019-06-28  Bronze
#
#       contract_type  amount
#  0              NEW   19.35
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   19.35
#  4              NEW   14.25
#  ...            ...     ...
#  8569           NEW   14.25
#  8570           NEW   14.25
#  8571           NEW   14.25
#  8572           NEW   19.35
#  8573           NEW   12.20
#
#  [8574 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          7e189393        Chicago  ACTIVE       2019-03-01  Silver
#  1          ed416609  Washington DC  ACTIVE       2019-03-01  Silver
#  2          c575e712       New York  ACTIVE       2019-03-01  Bronze
#  3          e47af516  San Francisco  ACTIVE       2019-03-01  Silver
#  4          a19ba534       New York  ACTIVE       2019-03-01    Gold
#  ...             ...            ...     ...              ...     ...
#  7559       02050375      Las Vegas  ACTIVE       2019-03-29  Silver
#  7560       18353e1e  San Francisco  ACTIVE       2019-03-29  Bronze
#  7561       8d1f10ff  San Francisco  ACTIVE       2019-03-29  Silver
#  7562       d773cecc  San Francisco  ACTIVE       2019-03-29  Silver
#  7563       b17d5751        Chicago  ACTIVE       2019-03-29  Silver
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   12.20
#  3              NEW   14.25
#  4              NEW   19.35
#  ...            ...     ...
#  7559           NEW   14.25
#  7560           NEW   12.20
#  7561           NEW   14.25
#  7562           NEW   14.25
#  7563           NEW   14.25
#
#  [7564 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          449d4aa9       New York  ACTIVE       2019-05-01  Bronze
#  1          6b38f1e5  San Francisco  ACTIVE       2019-05-01  Bronze
#  2          18ec3257  San Francisco  ACTIVE       2019-05-01  Bronze
#  3          4eeb8941  Washington DC  ACTIVE       2019-05-01  Silver
#  4          5e00fae5         Boston  ACTIVE       2019-05-01  Bronze
#  ...             ...            ...     ...              ...     ...
#  7227       3c2155e1        Chicago  ACTIVE       2019-05-31  Silver
#  7228       7ec4f241  Washington DC  ACTIVE       2019-05-31  Silver
#  7229       2da9bdbd        Chicago  ACTIVE       2019-05-31  Silver
#  7230       3a153211  Washington DC  ACTIVE       2019-05-31    Gold
#  7231       3e0f1423  San Francisco  ACTIVE       2019-05-31  Silver
#
#       contract_type  amount
#  0              NEW   12.20
#  1              NEW   12.20
#  2              NEW   12.20
#  3              NEW   14.25
#  4              NEW   12.20
#  ...            ...     ...
#  7227           NEW   14.25
#  7228           NEW   14.25
#  7229           NEW   14.25
#  7230           NEW   19.35
#  7231           NEW   14.25
#
#  [7232 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          ceb84a6b       New York  ACTIVE       2019-11-01    Gold
#  1          940c49b6        Chicago  ACTIVE       2019-11-01  Silver
#  2          07b541d6       New York  ACTIVE       2019-11-01  Bronze
#  3          61d52a79       New York  ACTIVE       2019-11-01    Gold
#  4          3228dd2f        Chicago  ACTIVE       2019-11-01    Gold
#  ...             ...            ...     ...              ...     ...
#  8767       1bc005bd      Las Vegas  ACTIVE       2019-11-29  Bronze
#  8768       cedfdf42  San Francisco  ACTIVE       2019-11-29  Silver
#  8769       668109e8       New York  ACTIVE       2019-11-29  Bronze
#  8770       5135f21a       New York  ACTIVE       2019-11-29  Bronze
#  8771       df2efc44        Chicago  ACTIVE       2019-11-29  Silver
#
#       contract_type  amount
#  0              NEW   19.35
#  1              NEW   14.25
#  2              NEW   12.20
#  3              NEW   19.35
#  4              NEW   19.35
#  ...            ...     ...
#  8767           NEW   12.20
#  8768           NEW   14.25
#  8769           NEW   12.20
#  8770           NEW   12.20
#  8771           NEW   14.25
#
#  [8772 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          a5196775  San Francisco  ACTIVE       2019-10-01  Silver
#  1          24f5b1bd       New York  ACTIVE       2019-10-01  Silver
#  2          7d3a57e3  San Francisco  ACTIVE       2019-10-01  Silver
#  3          1b8c6651         Boston  ACTIVE       2019-10-01  Bronze
#  4          0e42361a         Boston  ACTIVE       2019-10-01  Silver
#  ...             ...            ...     ...              ...     ...
#  5714       0240388f  San Francisco  ACTIVE       2019-10-31  Silver
#  5715       5dd35b12  San Francisco  ACTIVE       2019-10-31    Gold
#  5716       54777a09        Chicago  ACTIVE       2019-10-31  Silver
#  5717       d3fba6d1       New York  ACTIVE       2019-10-31  Silver
#  5718       68defd25        Chicago  ACTIVE       2019-10-31    Gold
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   12.20
#  4              NEW   14.25
#  ...            ...     ...
#  5714           NEW   14.25
#  5715           NEW   19.35
#  5716           NEW   14.25
#  5717           NEW   14.25
#  5718           NEW   19.35
#
#  [5719 rows x 7 columns],
#       transaction_id          store  status transaction_date    plan  \
#  0          1625da17       New York  ACTIVE       2019-09-02  Silver
#  1          a60801a8         Boston  ACTIVE       2019-09-02  Silver
#  2          478f5985       New York  ACTIVE       2019-09-02  Silver
#  3          ca84fd4c      Las Vegas  ACTIVE       2019-09-02  Silver
#  4          69fa39a9         Boston  ACTIVE       2019-09-02  Bronze
#  ...             ...            ...     ...              ...     ...
#  7347       53a449b0       New York  ACTIVE       2019-09-30  Silver
#  7348       35b46c26         Boston  ACTIVE       2019-09-30  Silver
#  7349       9e498c85        Chicago  ACTIVE       2019-09-30  Silver
#  7350       5841d16e  San Francisco  ACTIVE       2019-09-30  Silver
#  7351       86937799        Chicago  ACTIVE       2019-09-30    Gold
#
#       contract_type  amount
#  0              NEW   14.25
#  1              NEW   14.25
#  2              NEW   14.25
#  3              NEW   14.25
#  4              NEW   12.20
#  ...            ...     ...
#  7347           NEW   14.25
#  7348           NEW   14.25
#  7349           NEW   14.25
#  7350           NEW   14.25
#  7351           NEW   19.35
#
#  [7352 rows x 7 columns]]

# %%
df_summary = pd.concat(df_lists)
df_summary
# Out:
#      transaction_id          store  status transaction_date    plan  \
# 0          7fb801a5        Chicago  ACTIVE       2019-04-01  Silver
# 1          8e8bdb2a  San Francisco  ACTIVE       2019-04-01  Silver
# 2          239db9b6  Washington DC  ACTIVE       2019-04-01  Silver
# 3          7ccb13ab  San Francisco  ACTIVE       2019-04-01    Gold
# 4          c18e82d9        Chicago  ACTIVE       2019-04-01  Bronze
# ...             ...            ...     ...              ...     ...
# 7347       53a449b0       New York  ACTIVE       2019-09-30  Silver
# 7348       35b46c26         Boston  ACTIVE       2019-09-30  Silver
# 7349       9e498c85        Chicago  ACTIVE       2019-09-30  Silver
# 7350       5841d16e  San Francisco  ACTIVE       2019-09-30  Silver
# 7351       86937799        Chicago  ACTIVE       2019-09-30    Gold
#
#      contract_type  amount
# 0              NEW   14.25
# 1              NEW   14.25
# 2              NEW   14.25
# 3              NEW   19.35
# 4              NEW   12.20
# ...            ...     ...
# 7347           NEW   14.25
# 7348           NEW   14.25
# 7349           NEW   14.25
# 7350           NEW   14.25
# 7351           NEW   19.35
#
# [93583 rows x 7 columns]

# %%
pivot = pd.pivot_table(df_summary,index="transaction_date",columns="store",values="amount",aggfunc="sum")
pivot
# Out:
# store             Boston  Chicago  Las Vegas  New York  San Francisco  \
# transaction_date
# 2019-01-01        465.15  1277.25     269.70   1740.25        1739.20
# 2019-01-02        621.80  1177.50     369.45   1833.85        1861.45
# 2019-01-03        449.85  1204.95     302.25   1614.05        1736.20
# 2019-01-04        600.45  1165.25     340.95   1712.95        1763.75
# 2019-01-07        599.40  1197.80     395.90   1427.70        1967.20
# ...                  ...      ...        ...       ...            ...
# 2019-12-25        499.75   894.55     282.95   1480.95        1575.40
# 2019-12-26        382.65   971.85     298.25   1260.90        1427.75
# 2019-12-27        525.20   821.30     262.55   1429.75        1758.45
# 2019-12-30        300.25  1086.90     337.90   1460.40        1405.30
# 2019-12-31        484.50  1060.55     319.50   1554.00        1490.05
#
# store             Washington DC
# transaction_date
# 2019-01-01               355.15
# 2019-01-02               326.70
# 2019-01-03               286.95
# 2019-01-04               204.55
# 2019-01-07               265.65
# ...                         ...
# 2019-12-25               224.85
# 2019-12-26               193.35
# 2019-12-27               209.60
# 2019-12-30               235.10
# 2019-12-31               172.00
#
# [261 rows x 6 columns]

# %%
summary_monthly = pivot.resample("M").sum()
summary_monthly
# Out:
# store               Boston   Chicago  Las Vegas  New York  San Francisco  \
# transaction_date
# 2019-01-31        13701.10  26272.65    7216.45  42128.25       42969.25
# 2019-02-28        12243.85  24739.90    6192.60  37926.55       36469.35
# 2019-03-31        11026.60  22131.00    5637.25  32805.60       33876.45
# 2019-04-30        10344.80  21489.35    5540.40  32954.35       33265.00
# 2019-05-31        10533.15  20606.55    5266.45  32348.55       31836.80
# 2019-06-30        13317.90  24328.15    5713.55  38543.65       37787.30
# 2019-07-31        10701.65  20877.90    5376.65  31547.60       31386.65
# 2019-08-31        12239.70  24662.75    6335.05  36491.60       36895.10
# 2019-09-30        10757.10  20964.35    5928.55  33226.20       31709.80
# 2019-10-31         8180.35  16446.30    4217.25  24889.95       26015.90
# 2019-11-30        12583.90  25794.75    6880.75  38646.20       38479.20
# 2019-12-31        10390.00  21619.95    5481.60  32828.10       32378.60
#
# store             Washington DC
# transaction_date
# 2019-01-31              6515.40
# 2019-02-28              6705.70
# 2019-03-31              5173.80
# 2019-04-30              5480.30
# 2019-05-31              5293.95
# 2019-06-30              5926.05
# 2019-07-31              4982.55
# 2019-08-31              6729.15
# 2019-09-30              5544.45
# 2019-10-31              4171.45
# 2019-11-30              6035.00
# 2019-12-31              5245.00

# %%
import matplotlib
fig = summary_monthly.plot(kind="bar",figsize=(20,12),fontsize="26",title="monthly sale summary").get_figure()

# %%
import xlwings as xw

import datetime
now = datetime.datetime.now()
date_file_name = f'{str(now.date())}_{str(now.time()).split(".")[0].replace(":","_")}'


template = xw.Book(r"D:\NMB-Traning_Python\src\export\sale_template.xlsx")

app = xw.apps.active
sheet = template.sheets["summary"]
sheet["A1"].value = summary_monthly

pivot_page = template.sheets["pivot"]
pivot_page["A1"].value = pivot

#add picture
sheet_report = template.sheets["report"]
sheet_report["A1"].value = "Summary by month"
sheet_report['A1'].font.size = 24
sheet_report["A1"].api.Font.Bold = True
plot= sheet_report.pictures.add(fig,top=sheet["A3"].top,left=sheet["A3"].left)
plot.width = plot.width*0.8
plot.height = plot.height*0.8

template.save(f"export\summary_sale_report_{date_file_name}.xlsx")
template.close()
app.kill()
