# %%
# !pip install tk

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import filedialog,messagebox

path = None
save_as_dir = None

def sale_report(path,save_as):
    import pandas as pd
    import os
    import datetime

    today = datetime.date.today()
    year = today.year-1


    xlsx_file_lists = []
  
    for root,dirs,files in os.walk(path):
        for name in files:
            file_path = os.path.join(root,name)
            xlsx_file_lists.append(file_path)

    df_lists = []
    for f in xlsx_file_lists:
        if f.split("\\")[-2] == str(year):
            df = pd.read_excel(f)
            df_lists.append(df) #making list of df

    df_sumary = pd.concat(df_lists)
    df_sumary

    pivot = pd.pivot_table(df_sumary,
        index="transaction_date",
        columns="store",
        values="amount",
        aggfunc="sum")

    summary_monthly = pivot.resample("M").sum()
    summary_monthly

    import matplotlib
    fig = summary_monthly.plot(kind="bar",figsize=(20,12),fontsize=26,title="Monthly sale summary").get_figure()

    import xlwings as xw

    import datetime
    now = datetime.datetime.now()
    date_file_name = f'{str(now.date())}_{str(now.time()).split(".")[0].replace(":","_")}'


    template = xw.Book(r"data\sale_template.xlsx")

    app = xw.apps.active
    sheet = template.sheets["summary"]
    sheet["A1"].value = summary_monthly

    pivote = template.sheets["pivot"]
    pivote["A1"].value = pivot

    # add picture
    sheet_report = template.sheets["report"]
    sheet_report["A1"].value = "Summary by month"
    sheet_report['A1'].font.size = 24
    sheet_report["A1"].api.Font.Bold = True
    plot= sheet_report.pictures.add(fig,top=sheet["A3"].top,left=sheet["A3"].left)
    plot.width = plot.width*0.8
    plot.height = plot.height*0.8

    template.save(f"{save_as}.xlsx")
    template.close()
    app.kill()


def browse_files():
    global path

    file_name = filedialog.askdirectory()
    path = file_name
    file_explorer_label.configure(text=path)


def save_as():
    global save_as_dir
    save_file = filedialog.asksaveasfilename(initialdir = "/",
                                          title = "save as a File",
                                          filetypes = (("excel files",
                                                        "*.xlsx*"),
                                                       ("all files",
                                                        "*.*")))
    save_as_dir = save_file
    save_as_label.configure(text=save_as_dir)

def create_report_button_clicked():
    try:
        global path,save_as_dir
        print(f'path: {path}, save: {save_as_dir}')
        sale_report(path,save_as_dir)
        file_explorer_label.config(text="browse files")
        save_as_label.config(text="Save as")
        messagebox.showinfo("info","Done")
    except Exception as e:
        messagebox.showerror("Error!!",e)
        # print("Error",e)


#setup frame
window = tk.Tk()
window.title("Sale repot program")
window.geometry("640x120")
window.resizable(False,False)
frame = ttk.Frame(window)

#option
options = {'padx':5, 'pady':5}

#label browse_files
file_explorer_label = ttk.Label(frame, text="Browse files", width=85)
file_explorer_label.grid(column=0,row=0,**options)


#button browse_files
browse_files_btn = ttk.Button(frame,text='Browse')
browse_files_btn.grid(column=1,row=0,**options)
browse_files_btn.configure(command=browse_files)

#label save_as
save_as_label = ttk.Label(frame, text="Save as",width=85)
save_as_label.grid(column=0,row=1,**options)


#button save_as
save_as_button = ttk.Button(frame,text='File location')
save_as_button.grid(column=1,row=1,**options)
save_as_button.configure(command=save_as)


#button Create
create_button = ttk.Button(frame,text='CREATE!')
create_button.grid(columnspan=2,row=3,**options)
create_button.configure(command=create_report_button_clicked)


# add grid
frame.grid(pady=10,padx=10)

#loop gui
window.mainloop()
# Out:
# path: D:/NMB-Traning_Python/src/data/sales_data, save: D:/NMB-Traning_Python/src/export/test4

# %%
# !pip install pyinstaller
# Out:
# Requirement already satisfied: pyinstaller in d:\newenv\lib\site-packages (6.1.0)
# Requirement already satisfied: setuptools>=42.0.0 in d:\newenv\lib\site-packages (from pyinstaller) (68.0.0)
# Requirement already satisfied: altgraph in d:\newenv\lib\site-packages (from pyinstaller) (0.17.4)
# Requirement already satisfied: pyinstaller-hooks-contrib>=2021.4 in d:\newenv\lib\site-packages (from pyinstaller) (2023.10)
# Requirement already satisfied: packaging>=20.0 in d:\newenv\lib\site-packages (from pyinstaller) (23.2)
# Requirement already satisfied: pefile>=2022.5.30 in d:\newenv\lib\site-packages (from pyinstaller) (2023.2.7)
# Requirement already satisfied: pywin32-ctypes>=0.2.1 in d:\newenv\lib\site-packages (from pyinstaller) (0.2.2)
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# # Build

# %%
# !pyinstaller.exe --noconsole sale_report_tk.py
# Out:
# 2092 INFO: PyInstaller: 6.1.0
# 2093 INFO: Python: 3.10.13 (conda)
# 2113 INFO: Platform: Windows-10-10.0.19045-SP0
# 2115 INFO: wrote d:\NMB-Traning_Python\src\sale_report_tk.spec
# 2146 INFO: Extending PYTHONPATH with paths
# ['d:\\NMB-Traning_Python\\src']
# 3488 INFO: checking Analysis
# 3489 INFO: Building Analysis because Analysis-00.toc is non existent
# 3489 INFO: Initializing module dependency graph...
# 3491 INFO: Caching module graph hooks...
# 3729 INFO: Analyzing base_library.zip ...
# 7167 INFO: Loading module hook 'hook-heapq.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 7409 INFO: Loading module hook 'hook-encodings.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 11891 INFO: Loading module hook 'hook-pickle.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 17241 INFO: Caching module dependency graph...
# 17598 INFO: Running Analysis Analysis-00.toc
# 17599 INFO: Looking for Python shared library...
# 17880 INFO: Using Python shared library: D:\newenv\python310.dll
# 17880 INFO: Analyzing d:\NMB-Traning_Python\src\sale_report_tk.py
# 18379 INFO: Loading module hook 'hook-pandas.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 22322 INFO: Loading module hook 'hook-platform.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 22391 INFO: Loading module hook 'hook-sysconfig.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 22493 INFO: Loading module hook 'hook-numpy.py' from 'D:\\newenv\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 22595 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 24881 INFO: Loading module hook 'hook-difflib.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 25639 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 26387 INFO: Loading module hook 'hook-xml.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 30211 INFO: Loading module hook 'hook-psutil.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 34207 INFO: Loading module hook 'hook-pytz.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 34864 INFO: Loading module hook 'hook-pkg_resources.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 40959 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 46379 INFO: Loading module hook 'hook-IPython.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 52358 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 52942 INFO: Loading module hook 'hook-matplotlib.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 53771 INFO: Loading module hook 'hook-packaging.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 53961 INFO: Processing pre-safe import module hook gi from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 54213 INFO: Loading module hook 'hook-PIL.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 54399 INFO: Loading module hook 'hook-PIL.Image.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 57308 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 63086 INFO: Processing pre-safe import module hook six.moves from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 66479 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 69396 INFO: Loading module hook 'hook-pygments.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 74083 INFO: Loading module hook 'hook-importlib_metadata.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 75530 INFO: Loading module hook 'hook-lib2to3.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 77172 INFO: Loading module hook 'hook-wcwidth.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 80767 INFO: Loading module hook 'hook-jedi.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 83320 INFO: Loading module hook 'hook-parso.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 87603 INFO: Loading module hook 'hook-sqlite3.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 90620 INFO: Loading module hook 'hook-zmq.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 93928 INFO: Loading module hook 'hook-platformdirs.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 98275 INFO: Loading module hook 'hook-pandas.plotting.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 100696 INFO: Loading module hook 'hook-openpyxl.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 101815 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 109887 INFO: Loading module hook 'hook-pywintypes.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 110059 INFO: Loading module hook 'hook-pythoncom.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 110228 INFO: Processing pre-safe import module hook win32com from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 110469 INFO: Loading module hook 'hook-win32com.py' from 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 112594 INFO: Processing module hooks...
# 112730 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 112731 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 113520 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 113521 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 115242 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 125674 INFO: Loading module hook 'hook-_tkinter.py' from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks'...
# 125675 INFO: checking Tree
# 125675 INFO: Building Tree because Tree-00.toc is non existent
# 125675 INFO: Building Tree Tree-00.toc
# 125774 INFO: checking Tree
# 125774 INFO: Building Tree because Tree-01.toc is non existent
# 125774 INFO: Building Tree Tree-01.toc
# 125788 INFO: checking Tree
# 125788 INFO: Building Tree because Tree-02.toc is non existent
# 125788 INFO: Building Tree Tree-02.toc
# 163413 INFO: Looking for ctypes DLLs
# 163511 INFO: Analyzing run-time hooks ...
# 163539 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 163552 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 163566 INFO: Processing pre-find module path hook _pyi_rth_utils from 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 163612 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 163633 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 163636 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 163650 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 163671 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 163678 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 163700 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 163715 INFO: Including run-time hook 'D:\\newenv\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 164150 INFO: Looking for dynamic libraries
# D:\newenv\lib\site-packages\PyInstaller\isolated\_child.py:96: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   while run_next_command(read_fh, write_fh):
# D:\newenv\lib\site-packages\PyInstaller\building\build_main.py:194: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# 169435 INFO: Extra DLL search directories (AddDllDirectory): ['D:\\newenv\\lib\\site-packages\\numpy.libs', 'D:\\newenv\\lib\\site-packages\\matplotlib.libs', 'D:\\newenv\\lib\\site-packages\\matplotlib.libs', 'D:\\newenv\\lib\\site-packages\\pandas.libs']
# 169435 INFO: Extra DLL search directories (PATH): []
# 177118 INFO: Warnings written to d:\NMB-Traning_Python\src\build\sale_report_tk\warn-sale_report_tk.txt
# 177830 INFO: Graph cross-reference written to d:\NMB-Traning_Python\src\build\sale_report_tk\xref-sale_report_tk.html
# 178352 INFO: checking PYZ
# 178352 INFO: Building PYZ because PYZ-00.toc is non existent
# 178352 INFO: Building PYZ (ZlibArchive) d:\NMB-Traning_Python\src\build\sale_report_tk\PYZ-00.pyz
# 185730 INFO: Building PYZ (ZlibArchive) d:\NMB-Traning_Python\src\build\sale_report_tk\PYZ-00.pyz completed successfully.
# 186151 INFO: checking PKG
# 186152 INFO: Building PKG because PKG-00.toc is non existent
# 186152 INFO: Building PKG (CArchive) sale_report_tk.pkg
# 186322 INFO: Building PKG (CArchive) sale_report_tk.pkg completed successfully.
# 186338 INFO: Bootloader D:\newenv\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 186338 INFO: checking EXE
# 186340 INFO: Building EXE because EXE-00.toc is non existent
# 186340 INFO: Building EXE from EXE-00.toc
# 186341 INFO: Copying bootloader EXE to d:\NMB-Traning_Python\src\build\sale_report_tk\sale_report_tk.exe
# 186776 INFO: Copying icon to EXE
# 187068 INFO: Copying 0 resources to EXE
# 187069 INFO: Embedding manifest in EXE
# 187301 INFO: Appending PKG archive to EXE
# 187339 INFO: Fixing EXE headers
# 190320 INFO: Building EXE from EXE-00.toc completed successfully.
# 190954 INFO: checking COLLECT
# 190954 INFO: Building COLLECT because COLLECT-00.toc is non existent
# 190956 INFO: Building COLLECT COLLECT-00.toc
# 207297 INFO: Building COLLECT COLLECT-00.toc completed successfully.
